# %%
import pandas as pd
import numpy as np
import re  # string mani
import os  # read fold info

# %% [markdown]
# #### Notes:
# * wave use: ADNI1, ADNIGO, ADNI2
#
# * CSF values in UPENNBIOMK_MASTER & ADNIMERGE is different, couldn't find how ADNIMERGE use it
#     -> multiple batches in UPENNBIOMK_MASTER, use the median -> standardized to ADNI1
#
# * find values start from MCI -> check 6m, 12m, 24m follow up
#
# * make the MCI with A/T/N values as a specific subgroup -> compare the prediction & feature importance
#
# Methods applied: catboost, light gbm, xgboost, gbm, random forest, logistic regression
#
# evaluation: MCC, accuracy...

# %%
# functions:
def d_overview(df):
    print(f"Dimension: {df.shape}")
    output = df.apply(lambda x: (x.dtype,x.isna().mean(),x.unique()), axis=0).T
    output.columns = ["dtype", "NaN_precentage","unique"]
    return output.sort_values(by="NaN_precentage", ascending=False)
    
def keep_median_row(group):
    if 'MEDIAN' in group['BATCH'].values:
        return group[group['BATCH'] == 'MEDIAN']
    else:
        return group.head(1)
def basic_clean(df, printna=False):
#     if printna:
#         print(df.apply(lambda x:sum(x.isin(["-1","-4",-1,-4]))))
    df.replace([-1,-4,"-1","-4"], np.nan, inplace=True)
    if 'update_stamp' in df.columns:
        df.drop('update_stamp', axis=1, inplace=True)
    df = df.loc[:, (df.isna().mean() <= 0.5) &   # rm >50% missingness
                ~(df.columns.str.contains('DATE'))  # drop dates
               ].reset_index(drop=True) 
    df['RID'] = df['RID'].astype(int)
    return df

# %%
path = "../../ADNI_testing/"
biomarker = pd.read_csv(f"{path}UPENNBIOMK_MASTER.csv")     # adni1
diagnosis = pd.read_csv(f"{path}DXSUM_PDXCONV_ADNIALL.csv")
symptoms = pd.read_csv(f"{path}ADSXLIST.csv")
bl_symptoms = pd.read_csv(f"{path}BLSCHECK.csv")
adnimerge = pd.read_csv("../../ADNIMERGE.csv")

# %%
## biomarker
# biomarker.apply(lambda x:sum(x.isin(["-1","-4",-1,-4])))  # no -1,-4 in biomarker
# keep the median value or single row batch:
biomarker = biomarker.groupby(['RID', 'VISCODE'], as_index=False) \
.apply(keep_median_row).reset_index(drop=True)
biomarker = biomarker.loc[:,['RID','VISCODE','ABETA','TAU','PTAU']] # keep useful cols
# diagnosis=diagnosis.loc[diagnosis["Phase"]!="ADNI3"] # rm ADNI3 for diagnosis
# diagnosis = basic_clean(diagnosis)
symptoms = basic_clean(symptoms)
bl_symptoms = basic_clean(bl_symptoms)
## merge the 4 dataset:
fulldata = pd.merge(biomarker, symptoms, left_on=['RID', 'VISCODE'],
                 right_on=['RID', 'VISCODE2'], how="left", suffixes=["","_y"])
fulldata = pd.merge(
    fulldata,bl_symptoms, on=['RID', 'VISCODE2'], how="left")
fulldata=fulldata.loc[:,~(fulldata.columns.str.contains(r"(_x|_y)"))]
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
pd.set_option('display.max_rows', 500) 
display(d_overview(fulldata))
# Out:
# Dimension: (2174, 119)
#                             dtype NaN_precentage  \
# FBB_bl                    float64            1.0
# FBB                       float64            1.0
# PIB_bl                    float64        0.99126
# PIB                       float64       0.964121
# DIGITSCOR                 float64       0.568537
# DIGITSCOR_bl              float64       0.519779
# EcogSPOrgan_bl            float64        0.50966
# EcogSPDivatt_bl           float64        0.49908
# EcogPtOrgan_bl            float64         0.4977
# EcogSPVisspat_bl          float64        0.49494
# EcogSPPlan_bl             float64        0.49218
# MOCA_bl                   float64        0.49034
# AV45_bl                   float64        0.48988
# EcogPtDivatt_bl           float64        0.48896
# EcogPtVisspat_bl          float64        0.48804
# EcogSPTotal_bl            float64        0.48804
# EcogSPMem_bl              float64       0.487121
# EcogSPLang_bl             float64       0.487121
# EcogPtPlan_bl             float64       0.485741
# EcogPtTotal_bl            float64       0.485281
# EcogPtMem_bl              float64       0.485281
# EcogPtLang_bl             float64       0.485281
# EcogSPOrgan               float64       0.469181
# EcogPtOrgan               float64       0.460902
# AV45                      float64       0.460902
# EcogSPDivatt              float64       0.460442
# EcogSPVisspat             float64       0.455382
# EcogSPPlan                float64       0.452162
# EcogPtDivatt              float64       0.449862
# EcogPtVisspat             float64       0.449862
# MOCA                      float64       0.447562
# EcogSPTotal               float64       0.447102
# EcogPtLang                float64       0.446642
# EcogPtPlan                float64       0.446642
# EcogSPLang                float64       0.446182
# EcogSPMem                 float64       0.446182
# EcogPtTotal               float64       0.446182
# EcogPtMem                 float64       0.445722
# FDG                       float64       0.270929
# FDG_bl                    float64        0.24747
# Entorhinal                float64       0.204232
# MidTemp                   float64       0.204232
# Fusiform                  float64       0.204232
# Hippocampus               float64       0.169733
# Entorhinal_bl             float64       0.153634
# Fusiform_bl               float64       0.153634
# MidTemp_bl                float64       0.153634
# Hippocampus_bl            float64       0.139834
# FLDSTRENG                  object       0.103956
# FLDSTRENG_bl               object       0.096136
# Ventricles                float64       0.086937
# WholeBrain                float64       0.064397
# Ventricles_bl             float64       0.044158
# ICV                       float64       0.037718
# IMAGEUID                  float64       0.037718
# FSVERSION                  object       0.037718
# TRABSCOR                  float64       0.034499
# PTAU_bl                    object       0.034499
# ABETA_bl                   object       0.034499
# TAU_bl                     object       0.034499
# WholeBrain_bl             float64       0.025299
# PTAU_x                     object       0.023459
# TAU_x                      object       0.023459
# ABETA_x                    object       0.023459
# TRABSCOR_bl               float64       0.022079
# RAVLT_perc_forgetting     float64       0.013339
# ADAS13                    float64        0.01242
# TAU_y                     float64        0.01242
# RAVLT_forgetting          float64         0.0092
# IMAGEUID_bl               float64        0.00828
# FSVERSION_bl               object        0.00828
# ICV_bl                    float64        0.00828
# RAVLT_learning            float64        0.00782
# RAVLT_immediate           float64        0.00782
# CDRSB                     float64        0.00736
# FAQ                       float64         0.0069
# ADAS13_bl                 float64        0.00644
# RAVLT_perc_forgetting_bl  float64        0.00506
# LDELTOTAL                 float64         0.0046
# ADAS11                    float64         0.0046
# FAQ_bl                    float64        0.00368
# RAVLT_forgetting_bl       float64        0.00322
# RAVLT_learning_bl         float64        0.00322
# RAVLT_immediate_bl        float64        0.00322
# ADASQ4                    float64        0.00322
# ADAS11_bl                 float64        0.00276
# mPACCdigit                float64        0.00276
# MMSE                      float64         0.0023
# mPACCtrailsB              float64         0.0023
# Month_bl                  float64        0.00138
# Years_bl                  float64        0.00138
# Month                     float64        0.00138
# M                         float64        0.00138
# update_stamp               object        0.00138
# PTAU_y                    float64        0.00138
# mPACCtrailsB_bl           float64        0.00138
# PTRACCAT                   object        0.00138
# ORIGPROT                   object        0.00138
# PTID                       object        0.00138
# SITE                      float64        0.00138
# EXAMDATE                   object        0.00138
# DX_bl                      object        0.00138
# AGE                       float64        0.00138
# PTGENDER                   object        0.00138
# PTEDUCAT                  float64        0.00138
# mPACCdigit_bl             float64        0.00138
# PTETHCAT                   object        0.00138
# PTMARRY                    object        0.00138
# APOE4                     float64        0.00138
# COLPROT                    object        0.00138
# DX                         object        0.00138
# EXAMDATE_bl                object        0.00138
# CDRSB_bl                  float64        0.00138
# ADASQ4_bl                 float64        0.00138
# MMSE_bl                   float64        0.00138
# LDELTOTAL_BL              float64        0.00138
# ABETA_y                   float64        0.00092
# VISCODE                    object            0.0
# RID                         int64            0.0
#
#                                                                      unique
# FBB_bl                                                                [nan]
# FBB                                                                   [nan]
# PIB_bl                    [nan, 1.49, 1.195, 1.8925, 1.5675, 1.835, 2.23...
# PIB                       [nan, 2.0725, 2.19, 1.22, 2.1825, 1.83, 1.7525...
# DIGITSCOR                 [25.0, 21.0, 30.0, 38.0, 44.0, 49.0, 41.0, 27....
# DIGITSCOR_bl              [25.0, 38.0, 49.0, 27.0, 30.0, 46.0, 60.0, 48....
# EcogSPOrgan_bl            [nan, 3.4, 1.0, 1.16667, 1.33333, 2.0, 1.66667...
# EcogSPDivatt_bl           [nan, 3.0, 1.25, 1.75, 2.5, 1.5, 2.75, 4.0, 2....
# EcogPtOrgan_bl            [nan, 1.16667, 2.0, 1.5, 2.16667, 1.0, 3.8, 3....
# EcogSPVisspat_bl          [nan, 1.28571, 1.57143, 1.0, 1.14286, 1.42857,...
# EcogSPPlan_bl             [nan, 2.0, 1.0, 1.6, 2.4, 1.4, 4.0, 3.33333, 2...
# MOCA_bl                   [nan, 28.0, 27.0, 26.0, 25.0, 24.0, 30.0, 23.0...
# AV45_bl                   [nan, 0.9692, 1.1551, 1.0485, 1.2986, 1.0023, ...
# EcogPtDivatt_bl           [nan, 1.75, 2.25, 1.25, 1.5, 1.0, 3.25, 4.0, 2...
# EcogPtVisspat_bl          [nan, 1.71429, 2.0, 1.0, 1.14286, 3.0, 2.28571...
# EcogSPTotal_bl            [nan, 1.97368, 1.33333, 1.53846, 1.38462, 1.15...
# EcogSPMem_bl              [nan, 1.5, 1.875, 1.25, 2.0, 2.5, 1.375, 3.0, ...
# EcogSPLang_bl             [nan, 1.66667, 1.11111, 1.44444, 1.55556, 1.0,...
# EcogPtPlan_bl             [nan, 1.0, 2.0, 1.4, 1.2, 2.8, 2.2, 1.6, 2.4, ...
# EcogPtTotal_bl            [nan, 1.58974, 2.10256, 1.34211, 1.5641, 1.410...
# EcogPtMem_bl              [nan, 2.0, 1.375, 1.875, 2.25, 2.66667, 1.625,...
# EcogPtLang_bl             [nan, 1.66667, 2.33333, 1.5, 1.33333, 1.22222,...
# EcogSPOrgan               [nan, 1.0, 4.0, 2.0, 2.6, 2.75, 1.33333, 3.2, ...
# EcogPtOrgan               [nan, 1.0, 1.16667, 1.33333, 1.5, 1.2, 1.66667...
# AV45                      [nan, 1.2139, 1.0189, 0.9632, 0.9416, 0.9936, ...
# EcogSPDivatt              [nan, 1.0, 3.75, 4.0, 2.66667, 1.25, 2.0, 2.5,...
# EcogSPVisspat             [nan, 1.0, 2.0, 2.85714, 1.14286, 1.4, 2.83333...
# EcogSPPlan                [nan, 1.0, 3.6, 3.8, 1.6, 1.4, 1.75, 2.4, 1.2,...
# EcogPtDivatt              [nan, 1.25, 1.66667, 1.0, 1.5, 2.0, 1.75, 2.25...
# EcogPtVisspat             [nan, 1.0, 1.14286, 1.16667, 1.28571, 2.0, 1.5...
# MOCA                      [nan, 23.0, 19.0, 22.0, 20.0, 25.0, 27.0, 30.0...
# EcogSPTotal               [nan, 1.02564, 3.2, 3.25641, 1.10256, 1.0, 1.0...
# EcogPtLang                [nan, 1.11111, 1.22222, 1.0, 1.44444, 2.66667,...
# EcogPtPlan                [nan, 1.0, 1.2, 1.4, 1.6, 2.25, 1.8, 2.4, 2.0,...
# EcogSPLang                [nan, 1.0, 2.0, 1.88889, 1.11111, 1.22222, 1.6...
# EcogSPMem                 [nan, 1.125, 3.875, 1.25, 1.0, 1.75, 1.875, 2....
# EcogPtTotal               [nan, 1.10256, 1.17143, 1.16667, 1.05128, 1.0,...
# EcogPtMem                 [nan, 1.25, 1.28571, 1.125, 1.0, 2.5, 2.875, 2...
# FDG                       [1.1086, 1.11626, nan, 1.25956, 1.2809, 1.2096...
# FDG_bl                    [1.1086, nan, 1.25956, 1.20965, 1.03941, 1.250...
# Entorhinal                [1791.0, 1596.0, 3983.0, 3519.0, 4433.0, 3609....
# MidTemp                   [18422.0, 17330.0, 19615.0, 19758.0, 21614.0, ...
# Fusiform                  [15506.0, 14617.0, 19036.0, 18691.0, 24788.0, ...
# Hippocampus               [5319.0, 5157.0, 6869.0, 6451.0, 7075.0, 6832....
# Entorhinal_bl             [1791.0, 3983.0, 4433.0, 4190.0, 2676.0, 3581....
# Fusiform_bl               [15506.0, 19036.0, 24788.0, 14043.0, 16761.0, ...
# MidTemp_bl                [18422.0, 19615.0, 21614.0, 20076.0, 19741.0, ...
# Hippocampus_bl            [5319.0, 6869.0, 7075.0, 6080.0, 5485.0, 6730....
# FLDSTRENG                                 [1.5 Tesla MRI, nan, 3 Tesla MRI]
# FLDSTRENG_bl                              [1.5 Tesla MRI, nan, 3 Tesla MRI]
# Ventricles                [84599.0, 90099.0, 39605.0, 38527.0, 34062.0, ...
# WholeBrain                [1129830.0, 1095640.0, 1154980.0, 1117390.0, 1...
# Ventricles_bl             [84599.0, 39605.0, 34062.0, 18757.0, 26820.0, ...
# ICV                       [1920690.0, 1903820.0, 1679440.0, 1656740.0, 1...
# IMAGEUID                  [32237.0, 35576.0, 64631.0, 59357.0, 32246.0, ...
# FSVERSION                 [Cross-Sectional FreeSurfer (FreeSurfer Versio...
# TRABSCOR                  [148.0, 126.0, 271.0, 240.0, 90.0, 83.0, 51.0,...
# PTAU_bl                   [22.83, 13.29, 33.43, 37.51, 31.26, 16.68, 15....
# ABETA_bl                  [741.5, 1501.0, 547.3, >1700, 357.4, 1582.0, 5...
# TAU_bl                    [239.7, 153.1, 337.0, 440.2, 329.9, 203.6, 170...
# WholeBrain_bl             [1129830.0, 1154980.0, 1116630.0, 948684.0, 10...
# PTAU_x                    [22.83, 24.18, 13.29, 13.3, 33.43, 34.04, 37.5...
# TAU_x                     [239.7, 251.7, 153.1, 159.7, 337.0, 334.1, 440...
# ABETA_x                   [741.5, 601.4, 1501.0, 1176.0, 547.3, 472.8, >...
# TRABSCOR_bl               [148.0, 271.0, 90.0, 51.0, 100.0, 101.0, 79.0,...
# RAVLT_perc_forgetting     [100.0, 36.3636, 12.5, 44.4444, 50.0, 25.0, 14...
# ADAS13                    [31.0, 35.0, 21.33, 22.0, 14.67, nan, 7.0, 5.0...
# TAU_y                     [61.4, 76.5, 41.8, 49.4, 116.0, 120.0, 125.0, ...
# RAVLT_forgetting          [4.0, 7.0, 1.0, 6.0, 3.0, 5.0, -2.0, 2.0, 0.0,...
# IMAGEUID_bl               [32237.0, 64631.0, 32246.0, 32264.0, 32270.0, ...
# FSVERSION_bl              [Cross-Sectional FreeSurfer (FreeSurfer Versio...
# ICV_bl                    [1920690.0, 1679440.0, 1640770.0, 1396070.0, 1...
# RAVLT_learning            [1.0, 2.0, 7.0, 4.0, 6.0, 5.0, 3.0, 8.0, 0.0, ...
# RAVLT_immediate           [22.0, 31.0, 37.0, 40.0, 51.0, 42.0, 20.0, 21....
# CDRSB                     [4.5, 3.5, 1.0, 0.0, 1.5, 5.0, 4.0, 2.0, 2.5, ...
# FAQ                       [10.0, 17.0, 0.0, 11.0, 15.0, 22.0, 6.0, 12.0,...
# ADAS13_bl                 [31.0, 21.33, 14.67, 7.0, 24.33, 8.33, 14.33, ...
# RAVLT_perc_forgetting_bl  [100.0, 36.3636, 44.4444, 25.0, 50.0, 23.0769,...
# LDELTOTAL                 [2.0, 0.0, 4.0, 5.0, 12.0, 15.0, 16.0, 18.0, 1...
# ADAS11                    [22.0, 24.0, 14.33, 15.0, 8.67, 5.67, 5.0, 3.0...
# FAQ_bl                    [10.0, 0.0, 11.0, 6.0, 1.0, 4.0, 2.0, nan, 7.0...
# RAVLT_forgetting_bl       [4.0, 3.0, 5.0, 6.0, 2.0, 7.0, 1.0, 8.0, nan, ...
# RAVLT_learning_bl         [1.0, 7.0, 4.0, 2.0, 6.0, 8.0, 5.0, 3.0, -1.0,...
# RAVLT_immediate_bl        [22.0, 37.0, 51.0, 20.0, 45.0, 40.0, 54.0, 29....
# ADASQ4                    [8.0, 10.0, 6.0, 7.0, 4.0, 3.0, 2.0, 9.0, 1.0,...
# ADAS11_bl                 [22.0, 14.33, 8.67, 5.0, 12.33, 4.33, 10.33, 3...
# mPACCdigit                [-16.2905, -21.0293, -8.43305, -9.07756, -1.89...
# MMSE                      [20.0, 17.0, 27.0, 26.0, 29.0, 30.0, 28.0, 24....
# mPACCtrailsB              [-15.8737, -19.8378, -9.45734, -10.3022, -1.56...
# Month_bl                  [0.0, 11.9672, 12.1639, 11.9016, 11.9344, 12.7...
# Years_bl                  [0.0, 0.999316, 1.01574, 0.99384, 0.996578, 1....
# Month                     [0.0, 12.0, 24.0, 48.0, 60.0, 54.0, 66.0, 84.0...
# M                         [0.0, 12.0, 24.0, 48.0, 60.0, 84.0, nan, 36.0,...
# update_stamp              [58:48.0, 01:40.0, 58:49.0, nan, 01:41.0, 58:5...
# PTAU_y                    [20.4, 21.1, 12.9, 13.5, 67.2, 40.5, 29.0, 39....
# mPACCtrailsB_bl           [-15.8737, -9.45734, -1.56702, 1.20871, -12.54...
# PTRACCAT                  [White, Black, nan, Asian, More than one, Am I...
# ORIGPROT                                        [ADNI1, nan, ADNIGO, ADNI2]
# PTID                      [011_S_0003, 022_S_0004, 011_S_0005, 011_S_000...
# SITE                      [11.0, 22.0, 67.0, 23.0, 35.0, 100.0, 99.0, 7....
# EXAMDATE                  [9/12/05, 9/12/06, 11/8/05, 11/14/06, 9/7/05, ...
# DX_bl                                        [AD, LMCI, CN, nan, EMCI, SMC]
# AGE                       [81.3, 67.5, 73.7, 84.5, 73.9, 78.5, 65.4, 73....
# PTGENDER                                                [Male, Female, nan]
# PTEDUCAT                  [18.0, 10.0, 16.0, 12.0, 9.0, 17.0, 14.0, 20.0...
# mPACCdigit_bl             [-16.2905, -8.43305, -1.89018, 0.623868, -13.6...
# PTETHCAT                       [Not Hisp/Latino, Hisp/Latino, nan, Unknown]
# PTMARRY                   [Married, Widowed, Divorced, Never married, na...
# APOE4                                                  [1.0, 0.0, 2.0, nan]
# COLPROT                                         [ADNI1, ADNIGO, ADNI2, nan]
# DX                                                 [Dementia, MCI, CN, nan]
# EXAMDATE_bl               [9/12/05, 11/8/05, 9/7/05, 9/19/05, 11/10/05, ...
# CDRSB_bl                  [4.5, 1.0, 0.0, 5.0, 4.0, 2.0, 1.5, 0.5, nan, ...
# ADASQ4_bl                 [8.0, 6.0, 4.0, 2.0, 10.0, 0.0, 5.0, 7.0, nan,...
# MMSE_bl                   [20.0, 27.0, 29.0, 28.0, 24.0, 26.0, 21.0, 30....
# LDELTOTAL_BL              [2.0, 4.0, 12.0, 16.0, 10.0, 9.0, 21.0, 8.0, 0...
# ABETA_y                   [131.0, 137.0, 256.0, 246.0, 116.0, 136.0, 268...
# VISCODE                             [bl, m12, m24, m48, m60, m84, m36, m72]
# RID                       [3, 4, 5, 8, 10, 14, 16, 19, 22, 23, 29, 31, 3...

# %%
# diagnosis["DXCHANGE"].value_counts()
pd.crosstab(fulldata["DX"], fulldata["ORIGPROT"])
# Out:
# ORIGPROT  ADNI1  ADNI2  ADNIGO
# DX
# CN          328    344       5
# Dementia    311    178       4
# MCI         410    425     166

# %%
# adnimerge
# adnimerge.columns
fulldata = pd.merge(adnimerge, biomarker, on=['RID', 'VISCODE'], how="right")
# df = df.dropna(thresh=2)
# adnimerge[["PTAU", "TAU", "ABETA"]].dropna(thresh=2)
fulldata.loc[:,["PTAU_y","PTAU_x", "TAU_y", "TAU_x"]]


y = (fulldata.PTAU_y - fulldata.PTAU_y.mean())/fulldata.PTAU_y.std()
x = fulldata["PTAU_x"][-fulldata["PTAU_x"].str.contains("[><]", na=False)]
x = x.astype(float)
x = (x - x.mean())/x.std()
# Out:
# 0      -0.449641
# 1      -0.515232
# 2      -0.092248
# 3      -0.068014
# 4       0.751946
#           ...
# 2169    1.328331
# 2170   -0.122146
# 2171    1.907525
# 2172    0.220818
# 2173    0.109637
# Length: 2174, dtype: float64

# %%
d_overview(fulldata)
# Out:
# Dimension: (2174, 119)
#                             dtype NaN_precentage  \
# FBB_bl                    float64            1.0
# FBB                       float64            1.0
# PIB_bl                    float64        0.99126
# PIB                       float64       0.964121
# DIGITSCOR                 float64       0.568537
# DIGITSCOR_bl              float64       0.519779
# EcogSPOrgan_bl            float64        0.50966
# EcogSPDivatt_bl           float64        0.49908
# EcogPtOrgan_bl            float64         0.4977
# EcogSPVisspat_bl          float64        0.49494
# EcogSPPlan_bl             float64        0.49218
# MOCA_bl                   float64        0.49034
# AV45_bl                   float64        0.48988
# EcogPtDivatt_bl           float64        0.48896
# EcogPtVisspat_bl          float64        0.48804
# EcogSPTotal_bl            float64        0.48804
# EcogSPMem_bl              float64       0.487121
# EcogSPLang_bl             float64       0.487121
# EcogPtPlan_bl             float64       0.485741
# EcogPtTotal_bl            float64       0.485281
# EcogPtMem_bl              float64       0.485281
# EcogPtLang_bl             float64       0.485281
# EcogSPOrgan               float64       0.469181
# EcogPtOrgan               float64       0.460902
# AV45                      float64       0.460902
# EcogSPDivatt              float64       0.460442
# EcogSPVisspat             float64       0.455382
# EcogSPPlan                float64       0.452162
# EcogPtDivatt              float64       0.449862
# EcogPtVisspat             float64       0.449862
# MOCA                      float64       0.447562
# EcogSPTotal               float64       0.447102
# EcogPtLang                float64       0.446642
# EcogPtPlan                float64       0.446642
# EcogSPLang                float64       0.446182
# EcogSPMem                 float64       0.446182
# EcogPtTotal               float64       0.446182
# EcogPtMem                 float64       0.445722
# FDG                       float64       0.270929
# FDG_bl                    float64        0.24747
# Entorhinal                float64       0.204232
# MidTemp                   float64       0.204232
# Fusiform                  float64       0.204232
# Hippocampus               float64       0.169733
# Entorhinal_bl             float64       0.153634
# Fusiform_bl               float64       0.153634
# MidTemp_bl                float64       0.153634
# Hippocampus_bl            float64       0.139834
# FLDSTRENG                  object       0.103956
# FLDSTRENG_bl               object       0.096136
# Ventricles                float64       0.086937
# WholeBrain                float64       0.064397
# Ventricles_bl             float64       0.044158
# ICV                       float64       0.037718
# IMAGEUID                  float64       0.037718
# FSVERSION                  object       0.037718
# TRABSCOR                  float64       0.034499
# PTAU_bl                    object       0.034499
# ABETA_bl                   object       0.034499
# TAU_bl                     object       0.034499
# WholeBrain_bl             float64       0.025299
# PTAU_x                     object       0.023459
# TAU_x                      object       0.023459
# ABETA_x                    object       0.023459
# TRABSCOR_bl               float64       0.022079
# RAVLT_perc_forgetting     float64       0.013339
# ADAS13                    float64        0.01242
# TAU_y                     float64        0.01242
# RAVLT_forgetting          float64         0.0092
# IMAGEUID_bl               float64        0.00828
# FSVERSION_bl               object        0.00828
# ICV_bl                    float64        0.00828
# RAVLT_learning            float64        0.00782
# RAVLT_immediate           float64        0.00782
# CDRSB                     float64        0.00736
# FAQ                       float64         0.0069
# ADAS13_bl                 float64        0.00644
# RAVLT_perc_forgetting_bl  float64        0.00506
# LDELTOTAL                 float64         0.0046
# ADAS11                    float64         0.0046
# FAQ_bl                    float64        0.00368
# RAVLT_forgetting_bl       float64        0.00322
# RAVLT_learning_bl         float64        0.00322
# RAVLT_immediate_bl        float64        0.00322
# ADASQ4                    float64        0.00322
# ADAS11_bl                 float64        0.00276
# mPACCdigit                float64        0.00276
# MMSE                      float64         0.0023
# mPACCtrailsB              float64         0.0023
# Month_bl                  float64        0.00138
# Years_bl                  float64        0.00138
# Month                     float64        0.00138
# M                         float64        0.00138
# update_stamp               object        0.00138
# PTAU_y                    float64        0.00138
# mPACCtrailsB_bl           float64        0.00138
# PTRACCAT                   object        0.00138
# ORIGPROT                   object        0.00138
# PTID                       object        0.00138
# SITE                      float64        0.00138
# EXAMDATE                   object        0.00138
# DX_bl                      object        0.00138
# AGE                       float64        0.00138
# PTGENDER                   object        0.00138
# PTEDUCAT                  float64        0.00138
# mPACCdigit_bl             float64        0.00138
# PTETHCAT                   object        0.00138
# PTMARRY                    object        0.00138
# APOE4                     float64        0.00138
# COLPROT                    object        0.00138
# DX                         object        0.00138
# EXAMDATE_bl                object        0.00138
# CDRSB_bl                  float64        0.00138
# ADASQ4_bl                 float64        0.00138
# MMSE_bl                   float64        0.00138
# LDELTOTAL_BL              float64        0.00138
# ABETA_y                   float64        0.00092
# VISCODE                    object            0.0
# RID                         int64            0.0
#
#                                                                      unique
# FBB_bl                                                                [nan]
# FBB                                                                   [nan]
# PIB_bl                    [nan, 1.49, 1.195, 1.8925, 1.5675, 1.835, 2.23...
# PIB                       [nan, 2.0725, 2.19, 1.22, 2.1825, 1.83, 1.7525...
# DIGITSCOR                 [25.0, 21.0, 30.0, 38.0, 44.0, 49.0, 41.0, 27....
# DIGITSCOR_bl              [25.0, 38.0, 49.0, 27.0, 30.0, 46.0, 60.0, 48....
# EcogSPOrgan_bl            [nan, 3.4, 1.0, 1.16667, 1.33333, 2.0, 1.66667...
# EcogSPDivatt_bl           [nan, 3.0, 1.25, 1.75, 2.5, 1.5, 2.75, 4.0, 2....
# EcogPtOrgan_bl            [nan, 1.16667, 2.0, 1.5, 2.16667, 1.0, 3.8, 3....
# EcogSPVisspat_bl          [nan, 1.28571, 1.57143, 1.0, 1.14286, 1.42857,...
# EcogSPPlan_bl             [nan, 2.0, 1.0, 1.6, 2.4, 1.4, 4.0, 3.33333, 2...
# MOCA_bl                   [nan, 28.0, 27.0, 26.0, 25.0, 24.0, 30.0, 23.0...
# AV45_bl                   [nan, 0.9692, 1.1551, 1.0485, 1.2986, 1.0023, ...
# EcogPtDivatt_bl           [nan, 1.75, 2.25, 1.25, 1.5, 1.0, 3.25, 4.0, 2...
# EcogPtVisspat_bl          [nan, 1.71429, 2.0, 1.0, 1.14286, 3.0, 2.28571...
# EcogSPTotal_bl            [nan, 1.97368, 1.33333, 1.53846, 1.38462, 1.15...
# EcogSPMem_bl              [nan, 1.5, 1.875, 1.25, 2.0, 2.5, 1.375, 3.0, ...
# EcogSPLang_bl             [nan, 1.66667, 1.11111, 1.44444, 1.55556, 1.0,...
# EcogPtPlan_bl             [nan, 1.0, 2.0, 1.4, 1.2, 2.8, 2.2, 1.6, 2.4, ...
# EcogPtTotal_bl            [nan, 1.58974, 2.10256, 1.34211, 1.5641, 1.410...
# EcogPtMem_bl              [nan, 2.0, 1.375, 1.875, 2.25, 2.66667, 1.625,...
# EcogPtLang_bl             [nan, 1.66667, 2.33333, 1.5, 1.33333, 1.22222,...
# EcogSPOrgan               [nan, 1.0, 4.0, 2.0, 2.6, 2.75, 1.33333, 3.2, ...
# EcogPtOrgan               [nan, 1.0, 1.16667, 1.33333, 1.5, 1.2, 1.66667...
# AV45                      [nan, 1.2139, 1.0189, 0.9632, 0.9416, 0.9936, ...
# EcogSPDivatt              [nan, 1.0, 3.75, 4.0, 2.66667, 1.25, 2.0, 2.5,...
# EcogSPVisspat             [nan, 1.0, 2.0, 2.85714, 1.14286, 1.4, 2.83333...
# EcogSPPlan                [nan, 1.0, 3.6, 3.8, 1.6, 1.4, 1.75, 2.4, 1.2,...
# EcogPtDivatt              [nan, 1.25, 1.66667, 1.0, 1.5, 2.0, 1.75, 2.25...
# EcogPtVisspat             [nan, 1.0, 1.14286, 1.16667, 1.28571, 2.0, 1.5...
# MOCA                      [nan, 23.0, 19.0, 22.0, 20.0, 25.0, 27.0, 30.0...
# EcogSPTotal               [nan, 1.02564, 3.2, 3.25641, 1.10256, 1.0, 1.0...
# EcogPtLang                [nan, 1.11111, 1.22222, 1.0, 1.44444, 2.66667,...
# EcogPtPlan                [nan, 1.0, 1.2, 1.4, 1.6, 2.25, 1.8, 2.4, 2.0,...
# EcogSPLang                [nan, 1.0, 2.0, 1.88889, 1.11111, 1.22222, 1.6...
# EcogSPMem                 [nan, 1.125, 3.875, 1.25, 1.0, 1.75, 1.875, 2....
# EcogPtTotal               [nan, 1.10256, 1.17143, 1.16667, 1.05128, 1.0,...
# EcogPtMem                 [nan, 1.25, 1.28571, 1.125, 1.0, 2.5, 2.875, 2...
# FDG                       [1.1086, 1.11626, nan, 1.25956, 1.2809, 1.2096...
# FDG_bl                    [1.1086, nan, 1.25956, 1.20965, 1.03941, 1.250...
# Entorhinal                [1791.0, 1596.0, 3983.0, 3519.0, 4433.0, 3609....
# MidTemp                   [18422.0, 17330.0, 19615.0, 19758.0, 21614.0, ...
# Fusiform                  [15506.0, 14617.0, 19036.0, 18691.0, 24788.0, ...
# Hippocampus               [5319.0, 5157.0, 6869.0, 6451.0, 7075.0, 6832....
# Entorhinal_bl             [1791.0, 3983.0, 4433.0, 4190.0, 2676.0, 3581....
# Fusiform_bl               [15506.0, 19036.0, 24788.0, 14043.0, 16761.0, ...
# MidTemp_bl                [18422.0, 19615.0, 21614.0, 20076.0, 19741.0, ...
# Hippocampus_bl            [5319.0, 6869.0, 7075.0, 6080.0, 5485.0, 6730....
# FLDSTRENG                                 [1.5 Tesla MRI, nan, 3 Tesla MRI]
# FLDSTRENG_bl                              [1.5 Tesla MRI, nan, 3 Tesla MRI]
# Ventricles                [84599.0, 90099.0, 39605.0, 38527.0, 34062.0, ...
# WholeBrain                [1129830.0, 1095640.0, 1154980.0, 1117390.0, 1...
# Ventricles_bl             [84599.0, 39605.0, 34062.0, 18757.0, 26820.0, ...
# ICV                       [1920690.0, 1903820.0, 1679440.0, 1656740.0, 1...
# IMAGEUID                  [32237.0, 35576.0, 64631.0, 59357.0, 32246.0, ...
# FSVERSION                 [Cross-Sectional FreeSurfer (FreeSurfer Versio...
# TRABSCOR                  [148.0, 126.0, 271.0, 240.0, 90.0, 83.0, 51.0,...
# PTAU_bl                   [22.83, 13.29, 33.43, 37.51, 31.26, 16.68, 15....
# ABETA_bl                  [741.5, 1501.0, 547.3, >1700, 357.4, 1582.0, 5...
# TAU_bl                    [239.7, 153.1, 337.0, 440.2, 329.9, 203.6, 170...
# WholeBrain_bl             [1129830.0, 1154980.0, 1116630.0, 948684.0, 10...
# PTAU_x                    [22.83, 24.18, 13.29, 13.3, 33.43, 34.04, 37.5...
# TAU_x                     [239.7, 251.7, 153.1, 159.7, 337.0, 334.1, 440...
# ABETA_x                   [741.5, 601.4, 1501.0, 1176.0, 547.3, 472.8, >...
# TRABSCOR_bl               [148.0, 271.0, 90.0, 51.0, 100.0, 101.0, 79.0,...
# RAVLT_perc_forgetting     [100.0, 36.3636, 12.5, 44.4444, 50.0, 25.0, 14...
# ADAS13                    [31.0, 35.0, 21.33, 22.0, 14.67, nan, 7.0, 5.0...
# TAU_y                     [61.4, 76.5, 41.8, 49.4, 116.0, 120.0, 125.0, ...
# RAVLT_forgetting          [4.0, 7.0, 1.0, 6.0, 3.0, 5.0, -2.0, 2.0, 0.0,...
# IMAGEUID_bl               [32237.0, 64631.0, 32246.0, 32264.0, 32270.0, ...
# FSVERSION_bl              [Cross-Sectional FreeSurfer (FreeSurfer Versio...
# ICV_bl                    [1920690.0, 1679440.0, 1640770.0, 1396070.0, 1...
# RAVLT_learning            [1.0, 2.0, 7.0, 4.0, 6.0, 5.0, 3.0, 8.0, 0.0, ...
# RAVLT_immediate           [22.0, 31.0, 37.0, 40.0, 51.0, 42.0, 20.0, 21....
# CDRSB                     [4.5, 3.5, 1.0, 0.0, 1.5, 5.0, 4.0, 2.0, 2.5, ...
# FAQ                       [10.0, 17.0, 0.0, 11.0, 15.0, 22.0, 6.0, 12.0,...
# ADAS13_bl                 [31.0, 21.33, 14.67, 7.0, 24.33, 8.33, 14.33, ...
# RAVLT_perc_forgetting_bl  [100.0, 36.3636, 44.4444, 25.0, 50.0, 23.0769,...
# LDELTOTAL                 [2.0, 0.0, 4.0, 5.0, 12.0, 15.0, 16.0, 18.0, 1...
# ADAS11                    [22.0, 24.0, 14.33, 15.0, 8.67, 5.67, 5.0, 3.0...
# FAQ_bl                    [10.0, 0.0, 11.0, 6.0, 1.0, 4.0, 2.0, nan, 7.0...
# RAVLT_forgetting_bl       [4.0, 3.0, 5.0, 6.0, 2.0, 7.0, 1.0, 8.0, nan, ...
# RAVLT_learning_bl         [1.0, 7.0, 4.0, 2.0, 6.0, 8.0, 5.0, 3.0, -1.0,...
# RAVLT_immediate_bl        [22.0, 37.0, 51.0, 20.0, 45.0, 40.0, 54.0, 29....
# ADASQ4                    [8.0, 10.0, 6.0, 7.0, 4.0, 3.0, 2.0, 9.0, 1.0,...
# ADAS11_bl                 [22.0, 14.33, 8.67, 5.0, 12.33, 4.33, 10.33, 3...
# mPACCdigit                [-16.2905, -21.0293, -8.43305, -9.07756, -1.89...
# MMSE                      [20.0, 17.0, 27.0, 26.0, 29.0, 30.0, 28.0, 24....
# mPACCtrailsB              [-15.8737, -19.8378, -9.45734, -10.3022, -1.56...
# Month_bl                  [0.0, 11.9672, 12.1639, 11.9016, 11.9344, 12.7...
# Years_bl                  [0.0, 0.999316, 1.01574, 0.99384, 0.996578, 1....
# Month                     [0.0, 12.0, 24.0, 48.0, 60.0, 54.0, 66.0, 84.0...
# M                         [0.0, 12.0, 24.0, 48.0, 60.0, 84.0, nan, 36.0,...
# update_stamp              [58:48.0, 01:40.0, 58:49.0, nan, 01:41.0, 58:5...
# PTAU_y                    [20.4, 21.1, 12.9, 13.5, 67.2, 40.5, 29.0, 39....
# mPACCtrailsB_bl           [-15.8737, -9.45734, -1.56702, 1.20871, -12.54...
# PTRACCAT                  [White, Black, nan, Asian, More than one, Am I...
# ORIGPROT                                        [ADNI1, nan, ADNIGO, ADNI2]
# PTID                      [011_S_0003, 022_S_0004, 011_S_0005, 011_S_000...
# SITE                      [11.0, 22.0, 67.0, 23.0, 35.0, 100.0, 99.0, 7....
# EXAMDATE                  [9/12/05, 9/12/06, 11/8/05, 11/14/06, 9/7/05, ...
# DX_bl                                        [AD, LMCI, CN, nan, EMCI, SMC]
# AGE                       [81.3, 67.5, 73.7, 84.5, 73.9, 78.5, 65.4, 73....
# PTGENDER                                                [Male, Female, nan]
# PTEDUCAT                  [18.0, 10.0, 16.0, 12.0, 9.0, 17.0, 14.0, 20.0...
# mPACCdigit_bl             [-16.2905, -8.43305, -1.89018, 0.623868, -13.6...
# PTETHCAT                       [Not Hisp/Latino, Hisp/Latino, nan, Unknown]
# PTMARRY                   [Married, Widowed, Divorced, Never married, na...
# APOE4                                                  [1.0, 0.0, 2.0, nan]
# COLPROT                                         [ADNI1, ADNIGO, ADNI2, nan]
# DX                                                 [Dementia, MCI, CN, nan]
# EXAMDATE_bl               [9/12/05, 11/8/05, 9/7/05, 9/19/05, 11/10/05, ...
# CDRSB_bl                  [4.5, 1.0, 0.0, 5.0, 4.0, 2.0, 1.5, 0.5, nan, ...
# ADASQ4_bl                 [8.0, 6.0, 4.0, 2.0, 10.0, 0.0, 5.0, 7.0, nan,...
# MMSE_bl                   [20.0, 27.0, 29.0, 28.0, 24.0, 26.0, 21.0, 30....
# LDELTOTAL_BL              [2.0, 4.0, 12.0, 16.0, 10.0, 9.0, 21.0, 8.0, 0...
# ABETA_y                   [131.0, 137.0, 256.0, 246.0, 116.0, 136.0, 268...
# VISCODE                             [bl, m12, m24, m48, m60, m84, m36, m72]
# RID                       [3, 4, 5, 8, 10, 14, 16, 19, 22, 23, 29, 31, 3...

# %%
pd.crosstab(fulldata.DX_bl, fulldata.VISCODE=="m12")
# Out:
# VISCODE  False  True
# DX_bl
# AD         277    74
# CN         491    96
# EMCI       397     0
# LMCI       585   156
# SMC         95     0
